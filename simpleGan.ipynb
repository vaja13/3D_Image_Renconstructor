# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
import numpy as np
import os
import binvox_rw

# %%
device = "cpu"
# if torch.backends.mps.is_available():
#     device = torch.device("mps")
device
# Out:
# 'cpu'

# %%
class Generator(nn.Module):
    def __init__(self,cube_length = 32,latent_dimension = 200):
        super(Generator,self).__init__()
        self.cube_len = cube_length
        self.latent_dim = latent_dimension
        self.init_size = cube_length//16

        padd = (1,1,1) 
        self.lin=nn.Linear(in_features=self.latent_dim,out_features=256*self.init_size*self.init_size*self.init_size )

        self.layer1 = nn.Sequential(
            nn.ConvTranspose3d(self.cube_len*8, self.cube_len*4, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len*4),
            nn.ReLU()
        )
        # self.layer2 = nn.Sequential(
        #     nn.ConvTranspose3d(self.cube_len*8, self.cube_len*4, kernel_size=4, stride=2, bias=False, padding=padd),
        #     nn.BatchNorm3d(self.cube_len*4),
        #     nn.ReLU()
        # )
        self.layer2 = nn.Sequential(
            nn.ConvTranspose3d(self.cube_len*4, self.cube_len*2, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len*2),
            nn.ReLU()
        )
        self.layer3 = nn.Sequential(
            nn.ConvTranspose3d(self.cube_len*2, self.cube_len, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len),
            nn.ReLU()
        )
        self.layer4 = nn.Sequential(
            nn.ConvTranspose3d(self.cube_len, self.cube_len//2, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len//2),
            nn.ReLU()
        )
        self.layer5 = nn.Sequential(
            # nn.ConvTranspose3d(self.cube_len, 1, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.Conv3d(self.cube_len//2, 1, kernel_size=3, stride=1,padding=1),
            nn.Tanh()
        )
    def forward(self, x):
        out = self.lin(x)
        # print("layer 1 before view",out.shape)

        obj=out.view(x.shape[0],256,self.init_size,self.init_size,self.init_size)
        # print("layer 1 after liner and view",obj.shape)
        # [batch,latent,1,1,1]
        obj = self.layer1(obj)
        # print("after layer 1",obj.shape)

        # [batch,256,2,2,2]
        obj = self.layer2(obj)
        # print("layer 2 after liner and view",obj.shape)

        # [batch,128,4,4,4]
        obj = self.layer3(obj)
        # print("layer 3 after liner and view",obj.shape)

        # [batch,64,8,8,8]
        obj = self.layer4(obj)
        # print("layer 4 after liner and view",obj.shape)

        # [batch,32,16,16,16]
        obj = self.layer5(obj)
        # print("layer 5 after liner and view",obj.shape)

        # [batch,1,32,32,32]

        return obj
    
class Discriminator(nn.Module):
    def __init__(self,cube_length = 32):
        super(Discriminator,self).__init__()
        self.cube_len = cube_length

        padd = (1,1,1)

        self.layer1 = nn.Sequential(
            nn.Conv3d(1, self.cube_len, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len),
            nn.LeakyReLU(0.01)
        )
        #16
        self.layer2 = nn.Sequential(
            nn.Conv3d(self.cube_len, self.cube_len*2, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len*2),
            nn.LeakyReLU(0.01)
        )
        #8
        self.layer3 = nn.Sequential(
            nn.Conv3d(self.cube_len*2, self.cube_len*4, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len*4),
            nn.LeakyReLU(0.01)
        )
        #4
        self.layer4 = nn.Sequential(
            nn.Conv3d(self.cube_len*4, self.cube_len*8, kernel_size=4, stride=2, bias=False, padding=padd),
            nn.BatchNorm3d(self.cube_len*8),
            nn.LeakyReLU(0.01)
        )
        #2
        # self.layer5 = nn.Sequential(
        #     nn.Conv3d(self.cube_len*8, 1, kernel_size=4, stride=2, bias=False, padding=padd),
        #     nn.Sigmoid()
        # )
        self.out=nn.Sequential(nn.Linear(256*((self.cube_len//(2**4))**3),2))

    def forward(self, x):
        # print(x.shape,"x")
        out = x.view(-1, 1, self.cube_len, self.cube_len,self.cube_len)
        # [batch,1,32,32,32]
        # print(out.size(),"disc l1 inp")

        out = self.layer1(out)
        # [batch,32,16,16,16]
        # print(out.size(),"disc l1 out")

        out = self.layer2(out)
        # [batch,64,8,8,8]
        # print(out.size(),"disc l2 out")

        out = self.layer3(out)
        # [batch,128,4,4,4]
        # print(out.size(),"disc l3 out")

        out = self.layer4(out)
        # [batch,256,2,2,2]
        # print(out.size(),"disc l4 out")

        # out = self.layer5(out)
        # print(out.size(),"disc l5 out")
        out=out.view(out.shape[0],-1)

        # [batch,200,1,1,1]
        pred=self.out(out)


        return pred

# %%
def readBinvox3DObject(path):
    with open(path, 'rb') as file:
        data = np.float32(binvox_rw.read_as_3d_array(file).data)
    return data


transform=transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize([0.5],[0.5])
    ]
)

class ShapeNetDataset(Dataset):
    """Custom Dataset compatible with torch.utils.data.DataLoader"""

    def __init__(self, data_path,transform):
        """Set the path for Data.

        Args:
            root: image directory.
            transform: Tensor transformer.
        """
        self.data_path = data_path
        self.listdir = os.listdir(self.data_path)
        self.transform = transform


    def __getitem__(self, index):
        
        model_3d_file = [name for name in self.listdir if name.endswith('.' + "binvox")][index]
        # print(self.data_path + model_3d_file)
        volume = readBinvox3DObject(self.data_path + model_3d_file)
        vol = self.transform(volume)
        # return torch.FloatTensor(volume)
        return torch.FloatTensor(vol)

    def __len__(self):
        return len([name for name in self.listdir if name.endswith('.' + "binvox")])

# %%
dsets_path = "data/train/"
print(dsets_path)
train_dataset = ShapeNetDataset(dsets_path,transform)
print(train_dataset[0].shape,type(train_dataset[0]))
torch.unique(train_dataset[1])
# Out:
# data/train/
# torch.Size([32, 32, 32]) <class 'torch.Tensor'>
# tensor([-1.,  1.])

# %%
train_dl = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

# %%
beta1,beta2 = 0.9,0.99
d_lr = float(0.0002)
g_lr = float(0.0002)
n_epochs = 1000
batch_size = 32
d_thresh = 0.75

# %%
disc = Discriminator(cube_length=32).to(device)
genr = Generator(cube_length=32,latent_dimension=200).to(device)

criterion = nn.CrossEntropyLoss().to(device)

D_optim = optim.Adam(disc.parameters(), lr=d_lr, betas=[beta1,beta2])
G_optim = optim.Adam(genr.parameters(), lr=g_lr, betas=[beta1,beta2])

# %%
import torch

def generateZ(z_dis,latent_dim,batch_size):
    if z_dis == "norm":
        Z = torch.normal(mean=0, std=0.33, size=(batch_size, latent_dim))
    elif z_dis == "uni":
        Z = torch.randn(size=(batch_size, latent_dim))  
    elif z_dis == "nothing":
        Z = torch.randn(size=(batch_size, latent_dim))
    else:
        print("z_dis is not normal or uniform")
        Z = None  #

    return Z.to(device)

# %%
import matplotlib.pyplot as plt
import os
import torch
import matplotlib.gridspec as gridspec

def plot_voxel(ax, voxels, title):
    # Move tensor to CPU and detach for plotting
    
    voxels = torch.Tensor(voxels)
    # Rotate to make the chair upright and face the viewer
    voxels = torch.rot90(voxels, k=1, dims=[0, 2])  # Adjust rotation based on orientation
    voxels = torch.rot90(voxels, k=-1, dims=[0, 1])  # Rotate to face the viewer

    # Apply threshold to get a boolean tensor
    voxels = (voxels >= 0)

    # Plot the voxels
    ax.voxels(voxels, edgecolor='k')
    ax.set_title(title)
    # ax.set_xticks([])
    # ax.set_yticks([])
    # ax.set_zticks([])

def SavePloat_Voxels(original_data, predicted_data, epoch):
    save_dir = 'binvox_images'
    os.makedirs(save_dir, exist_ok=True)

    # predicted_data = predicted_data.__ge__(0.5)
    # original_data = original_data.__ge__(0.5)

    fig = plt.figure(figsize=(12, 6))  # Adjusted figure size for two plots
    gs = gridspec.GridSpec(1, 2)  # 1 row, 2 columns for side-by-side plots
    gs.update(wspace=0.05, hspace=0.05)

    # Plot original data on the left
    ax1 = fig.add_subplot(gs[0], projection='3d')
    plot_voxel(ax1, original_data, title="Original")

    # Plot predicted data on the right
    ax2 = fig.add_subplot(gs[1], projection='3d')
    plot_voxel(ax2, predicted_data, title="Predicted")

    # Save the figure
    plt.savefig(os.path.join(save_dir, f'epoch_{epoch}_comparison.png'), bbox_inches='tight')
    plt.close()

# SavePloat_Voxels(torch.randn((1,32,32,32)),torch.randn((1,32,32,32)),1)
# SavePloat_Voxels(train_dataset[0],train_dataset[1],1)

# %%
def train_one_epoch(e,D_model,G_model,data_loader,criterion,D_optim,G_optim):
    D_model.train()
    G_model.train()
    G_loss = 0
    D_loss = 0
    for i,X in enumerate(data_loader):
        X = X.to(device)

        if X.size()[0] != int(batch_size):
            continue        # This is for last batch where number of image is less

        Z = generateZ("nothing",200,batch_size=batch_size).to(device)

        real_labels = torch.ones(batch_size).to(device).type(torch.int64)
        fake_labels = torch.zeros(batch_size).to(device).type(torch.int64)

# --------------------------------- Train the generator ---------------------------------#

        fake = G_model(Z)

        d_fake_pred = D_model(fake)
        
        G_loss = criterion(d_fake_pred, real_labels)

        G_optim.zero_grad()
        G_loss.backward()
        G_optim.step()
        
# --------------------------------- Train the discriminator ------------------------------#
        # [20,32,32,32]
        d_real_pred = D_model(X)
        d_real_loss = criterion(d_real_pred, real_labels)

        # fake = G_model(Z)
        d_fake_pred = D_model(fake.detach())
        d_fake_loss = criterion(d_fake_pred, fake_labels)
        
        D_loss = (d_real_loss + d_fake_loss)/2

        D_optim.zero_grad()
        D_loss.backward()
        D_optim.step()
       

        if (e +1)% 10 == 0 and i == 0:  # Save for the first batch of each epoch
            # Convert tensors to binvox compatible format
            original_image = X[0].cpu().detach()  # Original image (first example)
            predicted_image = fake[0][0].cpu().detach() # Predicted image (first example)
            # print(type(predicted_image),predicted_image)
            # predicted_image = np.where(predicted_image > 0, 1, 0)
            # Save the binvox images side by side
            SavePloat_Voxels(original_image, predicted_image, e+1)

    return D_loss,G_loss

# %%
for e in range(n_epochs):
    train_d_loss,train_g_loss = train_one_epoch(e,disc,genr,train_dl,criterion,D_optim,G_optim)
    print(f"--------Epoch {e+1} -------- \n -------- discriminator_loss : {train_d_loss} --------\n Generator_loss : {train_g_loss} --------")
# Out:
# --------Epoch 1 --------
#  -------- discriminator_loss : 0.31481003761291504 --------
#  Generator_loss : 0.8487815856933594 --------
# --------Epoch 2 --------
#  -------- discriminator_loss : 0.12524794042110443 --------
#  Generator_loss : 6.759894847869873 --------
# --------Epoch 3 --------
#  -------- discriminator_loss : 0.04349260777235031 --------
#  Generator_loss : 2.7754642963409424 --------
# --------Epoch 4 --------
#  -------- discriminator_loss : 0.011318733915686607 --------
#  Generator_loss : 4.474286079406738 --------
# --------Epoch 5 --------
#  -------- discriminator_loss : 0.006232726853340864 --------
#  Generator_loss : 7.586093425750732 --------
# --------Epoch 6 --------
#  -------- discriminator_loss : 0.0076972669921815395 --------
#  Generator_loss : 6.3617706298828125 --------
# --------Epoch 7 --------
#  -------- discriminator_loss : 0.026813244447112083 --------
#  Generator_loss : 3.4138689041137695 --------
# --------Epoch 8 --------
#  -------- discriminator_loss : 0.004392439499497414 --------
#  Generator_loss : 6.385517597198486 --------
# --------Epoch 9 --------
#  -------- discriminator_loss : 0.004306424874812365 --------
#  Generator_loss : 6.9660515785217285 --------
# --------Epoch 10 --------
#  -------- discriminator_loss : 0.004416681360453367 --------
#  Generator_loss : 5.524542808532715 --------
# --------Epoch 11 --------
#  -------- discriminator_loss : 0.00512347836047411 --------
#  Generator_loss : 5.181426048278809 --------
# --------Epoch 12 --------
#  -------- discriminator_loss : 0.0026710263919085264 --------
#  Generator_loss : 6.14679479598999 --------
# --------Epoch 13 --------
#  -------- discriminator_loss : 0.005230416543781757 --------
#  Generator_loss : 5.117281436920166 --------
# --------Epoch 14 --------
#  -------- discriminator_loss : 0.006580950692296028 --------
#  Generator_loss : 5.237216472625732 --------
# --------Epoch 15 --------
#  -------- discriminator_loss : 0.007978914305567741 --------
#  Generator_loss : 5.229301452636719 --------
# --------Epoch 16 --------
#  -------- discriminator_loss : 0.01122085191309452 --------
#  Generator_loss : 5.315388202667236 --------
# --------Epoch 17 --------
#  -------- discriminator_loss : 0.006381018552929163 --------
#  Generator_loss : 6.158342361450195 --------
# --------Epoch 18 --------
#  -------- discriminator_loss : 0.006112937815487385 --------
#  Generator_loss : 5.2715582847595215 --------
# --------Epoch 19 --------
#  -------- discriminator_loss : 0.004340666346251965 --------
#  Generator_loss : 5.719367980957031 --------
# --------Epoch 20 --------
#  -------- discriminator_loss : 0.00561433844268322 --------
#  Generator_loss : 5.667903423309326 --------
# --------Epoch 21 --------
#  -------- discriminator_loss : 0.012397454120218754 --------
#  Generator_loss : 6.19144344329834 --------
# --------Epoch 22 --------
#  -------- discriminator_loss : 0.0037527382373809814 --------
#  Generator_loss : 5.300192356109619 --------
# --------Epoch 23 --------
#  -------- discriminator_loss : 0.0019332097144797444 --------
#  Generator_loss : 6.690027236938477 --------
# --------Epoch 24 --------
#  -------- discriminator_loss : 0.004245520103722811 --------
#  Generator_loss : 5.364205360412598 --------
# --------Epoch 25 --------
#  -------- discriminator_loss : 0.0026799445040524006 --------
#  Generator_loss : 7.0514960289001465 --------
# --------Epoch 26 --------
#  -------- discriminator_loss : 0.0017179334536194801 --------
#  Generator_loss : 6.75311803817749 --------
# --------Epoch 27 --------
#  -------- discriminator_loss : 0.0037504401989281178 --------
#  Generator_loss : 6.264657974243164 --------
# --------Epoch 28 --------
#  -------- discriminator_loss : 0.0018585881916806102 --------
#  Generator_loss : 6.82550048828125 --------
# --------Epoch 29 --------
#  -------- discriminator_loss : 0.0024962013121694326 --------
#  Generator_loss : 6.840856552124023 --------
# --------Epoch 30 --------
#  -------- discriminator_loss : 0.0012917198473587632 --------
#  Generator_loss : 6.8086838722229 --------
# --------Epoch 31 --------
#  -------- discriminator_loss : 0.0007456533494405448 --------
#  Generator_loss : 7.28876256942749 --------
# --------Epoch 32 --------
#  -------- discriminator_loss : 0.0009448652854189277 --------
#  Generator_loss : 7.163493633270264 --------
# --------Epoch 33 --------
#  -------- discriminator_loss : 0.001125024864450097 --------
#  Generator_loss : 6.507570266723633 --------
# --------Epoch 34 --------
#  -------- discriminator_loss : 0.0007056868053041399 --------
#  Generator_loss : 7.442811965942383 --------
# --------Epoch 35 --------
#  -------- discriminator_loss : 0.0007288333727046847 --------
#  Generator_loss : 7.757434368133545 --------
# --------Epoch 36 --------
#  -------- discriminator_loss : 0.0007276776013895869 --------
#  Generator_loss : 7.19536018371582 --------
# --------Epoch 37 --------
#  -------- discriminator_loss : 0.0010172805050387979 --------
#  Generator_loss : 6.773355484008789 --------
# --------Epoch 38 --------
#  -------- discriminator_loss : 0.0007698123808950186 --------
#  Generator_loss : 7.295334339141846 --------
# --------Epoch 39 --------
#  -------- discriminator_loss : 0.0025441371835768223 --------
#  Generator_loss : 7.026043891906738 --------
# --------Epoch 40 --------
#  -------- discriminator_loss : 0.0010413110721856356 --------
#  Generator_loss : 6.812648773193359 --------
# --------Epoch 41 --------
#  -------- discriminator_loss : 0.00115136057138443 --------
#  Generator_loss : 7.182916164398193 --------
# --------Epoch 42 --------
#  -------- discriminator_loss : 0.0011253483826294541 --------
#  Generator_loss : 6.873911380767822 --------
# --------Epoch 43 --------
#  -------- discriminator_loss : 0.0016467464156448841 --------
#  Generator_loss : 6.898919582366943 --------
# --------Epoch 44 --------
#  -------- discriminator_loss : 0.0007838131859898567 --------
#  Generator_loss : 7.5693464279174805 --------
# --------Epoch 45 --------
#  -------- discriminator_loss : 0.0015416688984259963 --------
#  Generator_loss : 6.877647399902344 --------
# --------Epoch 46 --------
#  -------- discriminator_loss : 0.0020356853492558002 --------
#  Generator_loss : 6.609748840332031 --------
# --------Epoch 47 --------
#  -------- discriminator_loss : 0.0012541166506707668 --------
#  Generator_loss : 7.869292259216309 --------
# --------Epoch 48 --------
#  -------- discriminator_loss : 0.0023953088093549013 --------
#  Generator_loss : 6.3084845542907715 --------
# --------Epoch 49 --------
#  -------- discriminator_loss : 0.000953531067352742 --------
#  Generator_loss : 7.787364959716797 --------
# --------Epoch 50 --------
#  -------- discriminator_loss : 0.0023040890228003263 --------
#  Generator_loss : 6.439176082611084 --------
# --------Epoch 51 --------
#  -------- discriminator_loss : 0.0011727767996490002 --------
#  Generator_loss : 8.056504249572754 --------
# --------Epoch 52 --------
#  -------- discriminator_loss : 0.002177294809371233 --------
#  Generator_loss : 7.040684223175049 --------
# --------Epoch 53 --------
#  -------- discriminator_loss : 0.0009835701202973723 --------
#  Generator_loss : 7.435788631439209 --------
# --------Epoch 54 --------
#  -------- discriminator_loss : 0.001366716343909502 --------
#  Generator_loss : 8.004186630249023 --------
# --------Epoch 55 --------
#  -------- discriminator_loss : 0.0017057054210454226 --------
#  Generator_loss : 7.215723037719727 --------
# --------Epoch 56 --------
#  -------- discriminator_loss : 0.0014955347869545221 --------
#  Generator_loss : 7.544511318206787 --------
# --------Epoch 57 --------
#  -------- discriminator_loss : 0.0025516969617456198 --------
#  Generator_loss : 6.568206787109375 --------
# --------Epoch 58 --------
#  -------- discriminator_loss : 0.002186276949942112 --------
#  Generator_loss : 7.506813049316406 --------
# --------Epoch 59 --------
#  -------- discriminator_loss : 0.002253549639135599 --------
#  Generator_loss : 6.555046081542969 --------
# --------Epoch 60 --------
#  -------- discriminator_loss : 0.002513343933969736 --------
#  Generator_loss : 7.051700592041016 --------
# --------Epoch 61 --------
#  -------- discriminator_loss : 0.009722328744828701 --------
#  Generator_loss : 11.655243873596191 --------
# --------Epoch 62 --------
#  -------- discriminator_loss : 0.00030300221987999976 --------
#  Generator_loss : 8.539620399475098 --------
# --------Epoch 63 --------
#  -------- discriminator_loss : 0.00022776554396841675 --------
#  Generator_loss : 12.17734432220459 --------
# --------Epoch 64 --------
#  -------- discriminator_loss : 0.014003284275531769 --------
#  Generator_loss : 15.638772964477539 --------
# --------Epoch 65 --------
#  -------- discriminator_loss : 9.780169420992024e-06 --------
#  Generator_loss : 13.845146179199219 --------
# --------Epoch 66 --------
#  -------- discriminator_loss : 0.0004633833887055516 --------
#  Generator_loss : 8.295939445495605 --------
# --------Epoch 67 --------
#  -------- discriminator_loss : 9.945494093699381e-05 --------
#  Generator_loss : 15.9021577835083 --------
# --------Epoch 68 --------
#  -------- discriminator_loss : 0.4424017667770386 --------
#  Generator_loss : 17.864999771118164 --------
# --------Epoch 69 --------
#  -------- discriminator_loss : 6.766020760551328e-06 --------
#  Generator_loss : 16.62458038330078 --------
# --------Epoch 70 --------
#  -------- discriminator_loss : 3.2881311199162155e-05 --------
#  Generator_loss : 13.435998916625977 --------
# --------Epoch 71 --------
#  -------- discriminator_loss : 0.009441452100872993 --------
#  Generator_loss : 8.53564739227295 --------
# --------Epoch 72 --------
#  -------- discriminator_loss : 0.0009148991666734219 --------
#  Generator_loss : 7.896576404571533 --------
# --------Epoch 73 --------
#  -------- discriminator_loss : 0.02817886881530285 --------
#  Generator_loss : 4.4845733642578125 --------
# --------Epoch 74 --------
#  -------- discriminator_loss : 0.0012754870112985373 --------
#  Generator_loss : 10.704255104064941 --------
# --------Epoch 75 --------
#  -------- discriminator_loss : 0.00026520207757130265 --------
#  Generator_loss : 13.682708740234375 --------
# --------Epoch 76 --------
#  -------- discriminator_loss : 5.943381620454602e-05 --------
#  Generator_loss : 15.135649681091309 --------
# --------Epoch 77 --------
#  -------- discriminator_loss : 0.00028976306202821434 --------
#  Generator_loss : 15.468452453613281 --------
# --------Epoch 78 --------
#  -------- discriminator_loss : 0.0025463681668043137 --------
#  Generator_loss : 15.826433181762695 --------
# --------Epoch 79 --------
#  -------- discriminator_loss : 0.0021997173316776752 --------
#  Generator_loss : 15.610382080078125 --------
# --------Epoch 80 --------
#  -------- discriminator_loss : 0.0067884353920817375 --------
#  Generator_loss : 15.18924331665039 --------
# --------Epoch 81 --------
#  -------- discriminator_loss : 0.0015109761152416468 --------
#  Generator_loss : 14.019210815429688 --------
# --------Epoch 82 --------
#  -------- discriminator_loss : 0.00015233171870931983 --------
#  Generator_loss : 10.711039543151855 --------
# --------Epoch 83 --------
#  -------- discriminator_loss : 0.08996180444955826 --------
#  Generator_loss : 3.639899253845215 --------
# --------Epoch 84 --------
#  -------- discriminator_loss : 0.07058842480182648 --------
#  Generator_loss : 14.351814270019531 --------
# --------Epoch 85 --------
#  -------- discriminator_loss : 0.005178170278668404 --------
#  Generator_loss : 14.654146194458008 --------
# --------Epoch 86 --------
#  -------- discriminator_loss : 0.00023997962125577033 --------
#  Generator_loss : 13.010287284851074 --------
# --------Epoch 87 --------
#  -------- discriminator_loss : 0.0030512106604874134 --------
#  Generator_loss : 10.173492431640625 --------
# --------Epoch 88 --------
#  -------- discriminator_loss : 0.04749104380607605 --------
#  Generator_loss : 5.706977844238281 --------
# --------Epoch 89 --------
#  -------- discriminator_loss : 0.0018779902020469308 --------
#  Generator_loss : 8.489721298217773 --------
# --------Epoch 90 --------
#  -------- discriminator_loss : 0.001373895793221891 --------
#  Generator_loss : 8.04861831665039 --------
# --------Epoch 91 --------
#  -------- discriminator_loss : 0.006908162031322718 --------
#  Generator_loss : 6.699464321136475 --------
# --------Epoch 92 --------
#  -------- discriminator_loss : 0.004186836536973715 --------
#  Generator_loss : 7.845779895782471 --------
# --------Epoch 93 --------
#  -------- discriminator_loss : 0.012253053486347198 --------
#  Generator_loss : 7.174319267272949 --------
# --------Epoch 94 --------
#  -------- discriminator_loss : 0.008726678788661957 --------
#  Generator_loss : 5.7022199630737305 --------
# --------Epoch 95 --------
#  -------- discriminator_loss : 0.011830741539597511 --------
#  Generator_loss : 6.704536437988281 --------
# --------Epoch 96 --------
#  -------- discriminator_loss : 0.017423275858163834 --------
#  Generator_loss : 6.107682228088379 --------
# --------Epoch 97 --------
#  -------- discriminator_loss : 0.01525475736707449 --------
#  Generator_loss : 6.924788475036621 --------
# --------Epoch 98 --------
#  -------- discriminator_loss : 0.019153809174895287 --------
#  Generator_loss : 4.730047225952148 --------
# --------Epoch 99 --------
#  -------- discriminator_loss : 0.03372902423143387 --------
#  Generator_loss : 9.810346603393555 --------
# --------Epoch 100 --------
#  -------- discriminator_loss : 0.04086466133594513 --------
#  Generator_loss : 5.101522445678711 --------
# --------Epoch 101 --------
#  -------- discriminator_loss : 0.00943066831678152 --------
#  Generator_loss : 11.871234893798828 --------
# --------Epoch 102 --------
#  -------- discriminator_loss : 0.0032743175979703665 --------
#  Generator_loss : 12.24434757232666 --------
# --------Epoch 103 --------
#  -------- discriminator_loss : 0.004233021754771471 --------
#  Generator_loss : 12.654147148132324 --------
# --------Epoch 104 --------
#  -------- discriminator_loss : 0.004280101973563433 --------
#  Generator_loss : 11.251236915588379 --------
# --------Epoch 105 --------
#  -------- discriminator_loss : 0.004106237553060055 --------
#  Generator_loss : 10.212745666503906 --------
# --------Epoch 106 --------
#  -------- discriminator_loss : 0.0008190700900740921 --------
#  Generator_loss : 9.568347930908203 --------
# --------Epoch 107 --------
#  -------- discriminator_loss : 0.002644341206178069 --------
#  Generator_loss : 7.103662967681885 --------
# --------Epoch 108 --------
#  -------- discriminator_loss : 0.001042309682816267 --------
#  Generator_loss : 8.480059623718262 --------
# --------Epoch 109 --------
#  -------- discriminator_loss : 0.0004929851857014 --------
#  Generator_loss : 9.326154708862305 --------
# --------Epoch 110 --------
#  -------- discriminator_loss : 0.0019294790690764785 --------
#  Generator_loss : 9.34599781036377 --------
# --------Epoch 111 --------
#  -------- discriminator_loss : 0.003106185235083103 --------
#  Generator_loss : 6.772846698760986 --------
# --------Epoch 112 --------
#  -------- discriminator_loss : 0.001844151527620852 --------
#  Generator_loss : 7.404991149902344 --------
# --------Epoch 113 --------
#  -------- discriminator_loss : 0.005569865461438894 --------
#  Generator_loss : 8.174263954162598 --------
# --------Epoch 114 --------
#  -------- discriminator_loss : 0.010938101448118687 --------
#  Generator_loss : 5.950049877166748 --------
# --------Epoch 115 --------
#  -------- discriminator_loss : 0.00033271219581365585 --------
#  Generator_loss : 9.515230178833008 --------
# --------Epoch 116 --------
#  -------- discriminator_loss : 0.0002862623950932175 --------
#  Generator_loss : 10.587905883789062 --------
# --------Epoch 117 --------
#  -------- discriminator_loss : 0.0006514139822684228 --------
#  Generator_loss : 10.235295295715332 --------
# --------Epoch 118 --------
#  -------- discriminator_loss : 0.0007170618046075106 --------
#  Generator_loss : 9.28056526184082 --------
# --------Epoch 119 --------
#  -------- discriminator_loss : 0.0013731967192143202 --------
#  Generator_loss : 7.222386837005615 --------
# --------Epoch 120 --------
#  -------- discriminator_loss : 0.003280916251242161 --------
#  Generator_loss : 6.467061519622803 --------
# --------Epoch 121 --------
#  -------- discriminator_loss : 0.0014546425081789494 --------
#  Generator_loss : 8.015109062194824 --------
# --------Epoch 122 --------
#  -------- discriminator_loss : 0.0007326342165470123 --------
#  Generator_loss : 9.365985870361328 --------
# --------Epoch 123 --------
#  -------- discriminator_loss : 0.0005139057757332921 --------
#  Generator_loss : 9.89216423034668 --------
# --------Epoch 124 --------
#  -------- discriminator_loss : 0.0008247296209447086 --------
#  Generator_loss : 9.348187446594238 --------
# --------Epoch 125 --------
#  -------- discriminator_loss : 0.0012615418527275324 --------
#  Generator_loss : 8.062760353088379 --------
# --------Epoch 126 --------
#  -------- discriminator_loss : 0.0051750256679952145 --------
#  Generator_loss : 6.036593914031982 --------
# --------Epoch 127 --------
#  -------- discriminator_loss : 0.003032870125025511 --------
#  Generator_loss : 6.786571025848389 --------
# --------Epoch 128 --------
#  -------- discriminator_loss : 0.0013224397553130984 --------
#  Generator_loss : 7.243619441986084 --------
# --------Epoch 129 --------
#  -------- discriminator_loss : 0.003430041717365384 --------
#  Generator_loss : 6.345658302307129 --------
# --------Epoch 130 --------
#  -------- discriminator_loss : 0.0026395260356366634 --------
#  Generator_loss : 6.768344879150391 --------
# --------Epoch 131 --------
#  -------- discriminator_loss : 0.003011416643857956 --------
#  Generator_loss : 7.572893142700195 --------
# --------Epoch 132 --------
#  -------- discriminator_loss : 0.004577015060931444 --------
#  Generator_loss : 5.99795389175415 --------
# --------Epoch 133 --------
#  -------- discriminator_loss : 0.0022724273148924112 --------
#  Generator_loss : 7.282452583312988 --------
# --------Epoch 134 --------
#  -------- discriminator_loss : 0.0021218452602624893 --------
#  Generator_loss : 6.999147891998291 --------
# --------Epoch 135 --------
#  -------- discriminator_loss : 0.0037696727085858583 --------
#  Generator_loss : 6.1446051597595215 --------
# --------Epoch 136 --------
#  -------- discriminator_loss : 0.0032136302907019854 --------
#  Generator_loss : 8.434832572937012 --------
# --------Epoch 137 --------
#  -------- discriminator_loss : 0.004410427995026112 --------
#  Generator_loss : 6.250627517700195 --------
# --------Epoch 138 --------
#  -------- discriminator_loss : 0.004192258231341839 --------
#  Generator_loss : 9.006129264831543 --------
# --------Epoch 139 --------
#  -------- discriminator_loss : 0.002495750319212675 --------
#  Generator_loss : 8.510186195373535 --------
# --------Epoch 140 --------
#  -------- discriminator_loss : 0.0043898168951272964 --------
#  Generator_loss : 5.9397172927856445 --------
# --------Epoch 141 --------
#  -------- discriminator_loss : 0.0073937913402915 --------
#  Generator_loss : 9.840667724609375 --------
# --------Epoch 142 --------
#  -------- discriminator_loss : 0.005138885695487261 --------
#  Generator_loss : 5.986217021942139 --------
# --------Epoch 143 --------
#  -------- discriminator_loss : 0.0008885539136826992 --------
#  Generator_loss : 8.122878074645996 --------
# --------Epoch 144 --------
#  -------- discriminator_loss : 0.005749434698373079 --------
#  Generator_loss : 6.018259525299072 --------
# --------Epoch 145 --------
#  -------- discriminator_loss : 0.006532673258334398 --------
#  Generator_loss : 8.02250862121582 --------
# --------Epoch 146 --------
#  -------- discriminator_loss : 0.011947505176067352 --------
#  Generator_loss : 8.918315887451172 --------
# --------Epoch 147 --------
#  -------- discriminator_loss : 0.0057044182904064655 --------
#  Generator_loss : 5.119110107421875 --------
# --------Epoch 148 --------
#  -------- discriminator_loss : 0.0007444159127771854 --------
#  Generator_loss : 10.118963241577148 --------
# --------Epoch 149 --------
#  -------- discriminator_loss : 0.0017729457467794418 --------
#  Generator_loss : 10.85011100769043 --------
# --------Epoch 150 --------
#  -------- discriminator_loss : 0.00181390845682472 --------
#  Generator_loss : 9.366271018981934 --------
# --------Epoch 151 --------
#  -------- discriminator_loss : 0.0023882375098764896 --------
#  Generator_loss : 7.512547016143799 --------
# --------Epoch 152 --------
#  -------- discriminator_loss : 0.0034188239369541407 --------
#  Generator_loss : 6.411001205444336 --------
# --------Epoch 153 --------
#  -------- discriminator_loss : 0.0019084555096924305 --------
#  Generator_loss : 8.677101135253906 --------
# --------Epoch 154 --------
#  -------- discriminator_loss : 0.0075960527174174786 --------
#  Generator_loss : 5.2174177169799805 --------
# --------Epoch 155 --------
#  -------- discriminator_loss : 0.0005110090132802725 --------
#  Generator_loss : 9.276636123657227 --------
# --------Epoch 156 --------
#  -------- discriminator_loss : 0.0004587048606481403 --------
#  Generator_loss : 9.954252243041992 --------
# --------Epoch 157 --------
#  -------- discriminator_loss : 0.0019097503973171115 --------
#  Generator_loss : 7.188294410705566 --------
# --------Epoch 158 --------
#  -------- discriminator_loss : 0.0008796256734058261 --------
#  Generator_loss : 7.297333240509033 --------
# --------Epoch 159 --------
#  -------- discriminator_loss : 0.0011668470688164234 --------
#  Generator_loss : 8.453227996826172 --------
# --------Epoch 160 --------
#  -------- discriminator_loss : 0.006804164033383131 --------
#  Generator_loss : 6.691473484039307 --------
# --------Epoch 161 --------
#  -------- discriminator_loss : 0.003112213686108589 --------
#  Generator_loss : 8.432574272155762 --------
# --------Epoch 162 --------
#  -------- discriminator_loss : 0.004466429352760315 --------
#  Generator_loss : 7.83825159072876 --------
# --------Epoch 163 --------
#  -------- discriminator_loss : 0.001095898449420929 --------
#  Generator_loss : 10.201620101928711 --------
# --------Epoch 164 --------
#  -------- discriminator_loss : 0.002984527265653014 --------
#  Generator_loss : 13.243621826171875 --------
# --------Epoch 165 --------
#  -------- discriminator_loss : 0.00012087883806088939 --------
#  Generator_loss : 12.545682907104492 --------
# --------Epoch 166 --------
#  -------- discriminator_loss : 0.0004596023936755955 --------
#  Generator_loss : 9.283132553100586 --------
# --------Epoch 167 --------
#  -------- discriminator_loss : 0.0043294611386954784 --------
#  Generator_loss : 6.252740383148193 --------
# --------Epoch 168 --------
#  -------- discriminator_loss : 0.002335939323529601 --------
#  Generator_loss : 11.834800720214844 --------
# --------Epoch 169 --------
#  -------- discriminator_loss : 0.0013499627821147442 --------
#  Generator_loss : 10.659104347229004 --------
# --------Epoch 170 --------
#  -------- discriminator_loss : 0.022187110036611557 --------
#  Generator_loss : 4.277385711669922 --------
# --------Epoch 171 --------
#  -------- discriminator_loss : 0.01118913572281599 --------
#  Generator_loss : 15.689724922180176 --------
# --------Epoch 172 --------
#  -------- discriminator_loss : 0.004533496685326099 --------
#  Generator_loss : 16.221059799194336 --------
# --------Epoch 173 --------
#  -------- discriminator_loss : 3.259849836467765e-05 --------
#  Generator_loss : 13.92945671081543 --------
# --------Epoch 174 --------
#  -------- discriminator_loss : 0.024691907688975334 --------
#  Generator_loss : 8.313161849975586 --------
# --------Epoch 175 --------
#  -------- discriminator_loss : 0.0001887973048724234 --------
#  Generator_loss : 15.519248962402344 --------
# --------Epoch 176 --------
#  -------- discriminator_loss : 0.013939755037426949 --------
#  Generator_loss : 17.111421585083008 --------
# --------Epoch 177 --------
#  -------- discriminator_loss : 0.00020641880109906197 --------
#  Generator_loss : 17.20636749267578 --------
# --------Epoch 178 --------
#  -------- discriminator_loss : 0.003987716976553202 --------
#  Generator_loss : 16.381526947021484 --------
# --------Epoch 179 --------
#  -------- discriminator_loss : 0.0004777753783855587 --------
#  Generator_loss : 14.234624862670898 --------
# --------Epoch 180 --------
#  -------- discriminator_loss : 0.0023994746152311563 --------
#  Generator_loss : 12.45006275177002 --------
# --------Epoch 181 --------
#  -------- discriminator_loss : 0.00021843556896783412 --------
#  Generator_loss : 11.793776512145996 --------
# --------Epoch 182 --------
#  -------- discriminator_loss : 6.788854079786688e-05 --------
#  Generator_loss : 12.388116836547852 --------
# --------Epoch 183 --------
#  -------- discriminator_loss : 0.0002282560453750193 --------
#  Generator_loss : 11.296818733215332 --------
# --------Epoch 184 --------
#  -------- discriminator_loss : 0.0007369797676801682 --------
#  Generator_loss : 8.911622047424316 --------
# --------Epoch 185 --------
#  -------- discriminator_loss : 0.02167830616235733 --------
#  Generator_loss : 4.293811798095703 --------
# --------Epoch 186 --------
#  -------- discriminator_loss : 0.1042691320180893 --------
#  Generator_loss : 15.443937301635742 --------
# --------Epoch 187 --------
#  -------- discriminator_loss : 0.9846068024635315 --------
#  Generator_loss : 2.788527011871338 --------
# --------Epoch 188 --------
#  -------- discriminator_loss : 0.2891497015953064 --------
#  Generator_loss : 19.18246841430664 --------
# --------Epoch 189 --------
#  -------- discriminator_loss : 0.032460372895002365 --------
#  Generator_loss : 18.68844985961914 --------
# --------Epoch 190 --------
#  -------- discriminator_loss : 3.148970426991582e-05 --------
#  Generator_loss : 17.38144874572754 --------
# --------Epoch 191 --------
#  -------- discriminator_loss : 1.329892529611243e-05 --------
#  Generator_loss : 15.601202964782715 --------
# --------Epoch 192 --------
#  -------- discriminator_loss : 9.081957614398561e-06 --------
#  Generator_loss : 13.248306274414062 --------
# --------Epoch 193 --------
#  -------- discriminator_loss : 0.0012411554343998432 --------
#  Generator_loss : 8.633858680725098 --------
# --------Epoch 194 --------
#  -------- discriminator_loss : 0.0463438406586647 --------
#  Generator_loss : 4.659283638000488 --------
# --------Epoch 195 --------
#  -------- discriminator_loss : 0.009217123501002789 --------
#  Generator_loss : 6.856598377227783 --------
# --------Epoch 196 --------
#  -------- discriminator_loss : 0.00898223090916872 --------
#  Generator_loss : 8.391815185546875 --------
# --------Epoch 197 --------
#  -------- discriminator_loss : 0.009285613894462585 --------
#  Generator_loss : 9.601001739501953 --------
# --------Epoch 198 --------
#  -------- discriminator_loss : 0.003407346550375223 --------
#  Generator_loss : 11.071314811706543 --------
# --------Epoch 199 --------
#  -------- discriminator_loss : 0.04731859639286995 --------
#  Generator_loss : 11.640453338623047 --------
# --------Epoch 200 --------
#  -------- discriminator_loss : 0.010934360325336456 --------
#  Generator_loss : 11.446099281311035 --------
# --------Epoch 201 --------
#  -------- discriminator_loss : 0.002195042558014393 --------
#  Generator_loss : 10.369722366333008 --------
# --------Epoch 202 --------
#  -------- discriminator_loss : 0.0044176396913826466 --------
#  Generator_loss : 9.374938011169434 --------
# --------Epoch 203 --------
#  -------- discriminator_loss : 0.007577730808407068 --------
#  Generator_loss : 8.194113731384277 --------
# --------Epoch 204 --------
#  -------- discriminator_loss : 0.0035205045714974403 --------
#  Generator_loss : 7.710430145263672 --------
# --------Epoch 205 --------
#  -------- discriminator_loss : 0.009861418977379799 --------
#  Generator_loss : 8.059334754943848 --------
# --------Epoch 206 --------
#  -------- discriminator_loss : 0.009208989329636097 --------
#  Generator_loss : 6.3721184730529785 --------
# --------Epoch 207 --------
#  -------- discriminator_loss : 0.006853575352579355 --------
#  Generator_loss : 5.497341632843018 --------
# --------Epoch 208 --------
#  -------- discriminator_loss : 0.008434857241809368 --------
#  Generator_loss : 6.1714959144592285 --------
# --------Epoch 209 --------
#  -------- discriminator_loss : 0.012382547371089458 --------
#  Generator_loss : 7.318392276763916 --------
# --------Epoch 210 --------
#  -------- discriminator_loss : 0.006498120725154877 --------
#  Generator_loss : 7.235777854919434 --------
# --------Epoch 211 --------
#  -------- discriminator_loss : 0.0027930347714573145 --------
#  Generator_loss : 7.359422206878662 --------
# --------Epoch 212 --------
#  -------- discriminator_loss : 0.002628224901854992 --------
#  Generator_loss : 6.819202423095703 --------
# --------Epoch 213 --------
#  -------- discriminator_loss : 0.007886281237006187 --------
#  Generator_loss : 6.078063488006592 --------
# --------Epoch 214 --------
#  -------- discriminator_loss : 0.0048620509915053844 --------
#  Generator_loss : 5.6486101150512695 --------
# --------Epoch 215 --------
#  -------- discriminator_loss : 0.0031637363135814667 --------
#  Generator_loss : 5.868072509765625 --------
# --------Epoch 216 --------
#  -------- discriminator_loss : 0.004945894703269005 --------
#  Generator_loss : 5.178620338439941 --------
# --------Epoch 217 --------
#  -------- discriminator_loss : 0.007534872740507126 --------
#  Generator_loss : 4.685298919677734 --------
# --------Epoch 218 --------
#  -------- discriminator_loss : 0.014346104115247726 --------
#  Generator_loss : 6.43276309967041 --------
# --------Epoch 219 --------
#  -------- discriminator_loss : 0.028507396578788757 --------
#  Generator_loss : 6.72941255569458 --------
# --------Epoch 220 --------
#  -------- discriminator_loss : 0.004323285073041916 --------
#  Generator_loss : 5.320946216583252 --------
# --------Epoch 221 --------
#  -------- discriminator_loss : 0.0043881735764443874 --------
#  Generator_loss : 5.195162773132324 --------
# --------Epoch 222 --------
#  -------- discriminator_loss : 0.0007741924491710961 --------
#  Generator_loss : 7.335628509521484 --------
# --------Epoch 223 --------
#  -------- discriminator_loss : 0.001030018087476492 --------
#  Generator_loss : 8.159571647644043 --------
# --------Epoch 224 --------
#  -------- discriminator_loss : 0.0003758341772481799 --------
#  Generator_loss : 8.364912033081055 --------
# --------Epoch 225 --------
#  -------- discriminator_loss : 0.00032379801268689334 --------
#  Generator_loss : 8.993351936340332 --------
# --------Epoch 226 --------
#  -------- discriminator_loss : 0.0006710562156513333 --------
#  Generator_loss : 8.476197242736816 --------
# --------Epoch 227 --------
#  -------- discriminator_loss : 0.0022024603094905615 --------
#  Generator_loss : 7.794249057769775 --------
# --------Epoch 228 --------
#  -------- discriminator_loss : 0.0023441282100975513 --------
#  Generator_loss : 7.143495082855225 --------
# --------Epoch 229 --------
#  -------- discriminator_loss : 0.0011040573008358479 --------
#  Generator_loss : 7.110428333282471 --------
# --------Epoch 230 --------
#  -------- discriminator_loss : 0.0013179066590964794 --------
#  Generator_loss : 6.8677215576171875 --------
# --------Epoch 231 --------
#  -------- discriminator_loss : 0.0027295323088765144 --------
#  Generator_loss : 6.723649501800537 --------
# --------Epoch 232 --------
#  -------- discriminator_loss : 0.016512148082256317 --------
#  Generator_loss : 6.1701555252075195 --------
# --------Epoch 233 --------
#  -------- discriminator_loss : 0.00791431125253439 --------
#  Generator_loss : 9.059846878051758 --------
# --------Epoch 234 --------
#  -------- discriminator_loss : 0.006234905682504177 --------
#  Generator_loss : 8.953575134277344 --------
# --------Epoch 235 --------
#  -------- discriminator_loss : 0.010324965231120586 --------
#  Generator_loss : 5.602354526519775 --------
# --------Epoch 236 --------
#  -------- discriminator_loss : 0.03704134374856949 --------
#  Generator_loss : 3.148695468902588 --------
# --------Epoch 237 --------
#  -------- discriminator_loss : 0.01982712559401989 --------
#  Generator_loss : 10.396220207214355 --------
# --------Epoch 238 --------
#  -------- discriminator_loss : 0.019514810293912888 --------
#  Generator_loss : 11.229179382324219 --------
# --------Epoch 239 --------
#  -------- discriminator_loss : 0.01503513753414154 --------
#  Generator_loss : 6.8200273513793945 --------
# --------Epoch 240 --------
#  -------- discriminator_loss : 0.0066995276138186455 --------
#  Generator_loss : 4.910778999328613 --------
# --------Epoch 241 --------
#  -------- discriminator_loss : 0.034915320575237274 --------
#  Generator_loss : 6.072268962860107 --------
# --------Epoch 242 --------
#  -------- discriminator_loss : 0.00474933348596096 --------
#  Generator_loss : 7.939573287963867 --------
# --------Epoch 243 --------
#  -------- discriminator_loss : 0.006910118740051985 --------
#  Generator_loss : 8.625598907470703 --------
# --------Epoch 244 --------
#  -------- discriminator_loss : 0.0053476011380553246 --------
#  Generator_loss : 7.286035060882568 --------
# --------Epoch 245 --------
#  -------- discriminator_loss : 0.0037564048543572426 --------
#  Generator_loss : 7.182704448699951 --------
# --------Epoch 246 --------
#  -------- discriminator_loss : 0.0011800247011706233 --------
#  Generator_loss : 8.069808959960938 --------
# --------Epoch 247 --------
#  -------- discriminator_loss : 0.008171786554157734 --------
#  Generator_loss : 6.757260322570801 --------
# --------Epoch 248 --------
#  -------- discriminator_loss : 0.005282990634441376 --------
#  Generator_loss : 8.212515830993652 --------
# --------Epoch 249 --------
#  -------- discriminator_loss : 0.008515107445418835 --------
#  Generator_loss : 8.803747177124023 --------
# --------Epoch 250 --------
#  -------- discriminator_loss : 0.017789093777537346 --------
#  Generator_loss : 5.942982196807861 --------
# --------Epoch 251 --------
#  -------- discriminator_loss : 0.0017722626216709614 --------
#  Generator_loss : 10.509146690368652 --------
# --------Epoch 252 --------
#  -------- discriminator_loss : 0.0023267720825970173 --------
#  Generator_loss : 12.275108337402344 --------
# --------Epoch 253 --------
#  -------- discriminator_loss : 0.0007772801909595728 --------
#  Generator_loss : 12.327824592590332 --------
# --------Epoch 254 --------
#  -------- discriminator_loss : 0.00030756116029806435 --------
#  Generator_loss : 10.25994873046875 --------
# --------Epoch 255 --------
#  -------- discriminator_loss : 0.0010669105686247349 --------
#  Generator_loss : 9.04928970336914 --------
# --------Epoch 256 --------
#  -------- discriminator_loss : 0.00041800527833402157 --------
#  Generator_loss : 9.148807525634766 --------
# --------Epoch 257 --------
#  -------- discriminator_loss : 0.0022159116342663765 --------
#  Generator_loss : 11.967276573181152 --------
# --------Epoch 258 --------
#  -------- discriminator_loss : 0.0008686661603860557 --------
#  Generator_loss : 10.954545021057129 --------
# --------Epoch 259 --------
#  -------- discriminator_loss : 0.00020323769422248006 --------
#  Generator_loss : 8.845558166503906 --------
# --------Epoch 260 --------
#  -------- discriminator_loss : 0.0029740005265921354 --------
#  Generator_loss : 6.031348705291748 --------
# --------Epoch 261 --------
#  -------- discriminator_loss : 0.006567975506186485 --------
#  Generator_loss : 4.827147960662842 --------
# --------Epoch 262 --------
#  -------- discriminator_loss : 0.0004565604613162577 --------
#  Generator_loss : 10.106555938720703 --------
# --------Epoch 263 --------
#  -------- discriminator_loss : 0.00504401745274663 --------
#  Generator_loss : 11.857465744018555 --------
# --------Epoch 264 --------
#  -------- discriminator_loss : 0.0007796469726599753 --------
#  Generator_loss : 11.222825050354004 --------
# --------Epoch 265 --------
#  -------- discriminator_loss : 0.0005736104212701321 --------
#  Generator_loss : 8.965815544128418 --------
# --------Epoch 266 --------
#  -------- discriminator_loss : 0.00518096424639225 --------
#  Generator_loss : 5.059152126312256 --------
# --------Epoch 267 --------
#  -------- discriminator_loss : 0.000914764532353729 --------
#  Generator_loss : 8.325101852416992 --------
# --------Epoch 268 --------
#  -------- discriminator_loss : 0.0008890830795280635 --------
#  Generator_loss : 9.361326217651367 --------
# --------Epoch 269 --------
#  -------- discriminator_loss : 0.001303515862673521 --------
#  Generator_loss : 7.148472309112549 --------
# --------Epoch 270 --------
#  -------- discriminator_loss : 0.00022618092771153897 --------
#  Generator_loss : 11.268606185913086 --------
# --------Epoch 271 --------
#  -------- discriminator_loss : 0.07915699481964111 --------
#  Generator_loss : 16.527448654174805 --------
# --------Epoch 272 --------
#  -------- discriminator_loss : 6.273670442169532e-05 --------
#  Generator_loss : 13.687463760375977 --------
# --------Epoch 273 --------
#  -------- discriminator_loss : 0.00033936882391572 --------
#  Generator_loss : 9.808232307434082 --------
# --------Epoch 274 --------
#  -------- discriminator_loss : 0.008838295936584473 --------
#  Generator_loss : 6.139649868011475 --------
# --------Epoch 275 --------
#  -------- discriminator_loss : 0.0036891852505505085 --------
#  Generator_loss : 6.847957611083984 --------
# --------Epoch 276 --------
#  -------- discriminator_loss : 0.00012955762213096023 --------
#  Generator_loss : 9.706892967224121 --------
# --------Epoch 277 --------
#  -------- discriminator_loss : 5.477774902828969e-05 --------
#  Generator_loss : 10.974186897277832 --------
# --------Epoch 278 --------
#  -------- discriminator_loss : 7.381174509646371e-05 --------
#  Generator_loss : 11.253531455993652 --------
# --------Epoch 279 --------
#  -------- discriminator_loss : 0.0021869740448892117 --------
#  Generator_loss : 10.227730751037598 --------
# --------Epoch 280 --------
#  -------- discriminator_loss : 0.003711286000907421 --------
#  Generator_loss : 8.786048889160156 --------
# --------Epoch 281 --------
#  -------- discriminator_loss : 0.0031279250979423523 --------
#  Generator_loss : 7.032812595367432 --------
# --------Epoch 282 --------
#  -------- discriminator_loss : 0.011553691700100899 --------
#  Generator_loss : 8.575584411621094 --------
# --------Epoch 283 --------
#  -------- discriminator_loss : 0.0027038962580263615 --------
#  Generator_loss : 7.213170051574707 --------
# --------Epoch 284 --------
#  -------- discriminator_loss : 0.00031428522197529674 --------
#  Generator_loss : 9.395746231079102 --------
# --------Epoch 285 --------
#  -------- discriminator_loss : 0.0004126399871893227 --------
#  Generator_loss : 9.103145599365234 --------
# --------Epoch 286 --------
#  -------- discriminator_loss : 0.0017869964940473437 --------
#  Generator_loss : 7.612466812133789 --------
# --------Epoch 287 --------
#  -------- discriminator_loss : 0.0024641503114253283 --------
#  Generator_loss : 7.335936069488525 --------
# --------Epoch 288 --------
#  -------- discriminator_loss : 0.014137894846498966 --------
#  Generator_loss : 8.489056587219238 --------
# --------Epoch 289 --------
#  -------- discriminator_loss : 0.0010408377274870872 --------
#  Generator_loss : 8.618230819702148 --------
# --------Epoch 290 --------
#  -------- discriminator_loss : 0.0016336762346327305 --------
#  Generator_loss : 11.113224029541016 --------
# --------Epoch 291 --------
#  -------- discriminator_loss : 0.00016870736726559699 --------
#  Generator_loss : 10.933977127075195 --------
# --------Epoch 292 --------
#  -------- discriminator_loss : 0.0005475908401422203 --------
#  Generator_loss : 9.207307815551758 --------
# --------Epoch 293 --------
#  -------- discriminator_loss : 0.004222360905259848 --------
#  Generator_loss : 6.632912635803223 --------
# --------Epoch 294 --------
#  -------- discriminator_loss : 8.783705561654642e-05 --------
#  Generator_loss : 9.665480613708496 --------
# --------Epoch 295 --------
#  -------- discriminator_loss : 0.00030067827901802957 --------
#  Generator_loss : 9.700410842895508 --------
# --------Epoch 296 --------
#  -------- discriminator_loss : 0.001040034112520516 --------
#  Generator_loss : 7.761519908905029 --------
# --------Epoch 297 --------
#  -------- discriminator_loss : 0.005404896102845669 --------
#  Generator_loss : 6.320226669311523 --------
# --------Epoch 298 --------
#  -------- discriminator_loss : 0.004004340618848801 --------
#  Generator_loss : 5.196544170379639 --------
# --------Epoch 299 --------
#  -------- discriminator_loss : 0.0007091362494975328 --------
#  Generator_loss : 7.621090888977051 --------
# --------Epoch 300 --------
#  -------- discriminator_loss : 0.0005009329761378467 --------
#  Generator_loss : 8.11767864227295 --------
# --------Epoch 301 --------
#  -------- discriminator_loss : 0.003177075181156397 --------
#  Generator_loss : 6.509030342102051 --------
# --------Epoch 302 --------
#  -------- discriminator_loss : 0.0014109623152762651 --------
#  Generator_loss : 8.065622329711914 --------
# --------Epoch 303 --------
#  -------- discriminator_loss : 0.005257835611701012 --------
#  Generator_loss : 5.629238128662109 --------
# --------Epoch 304 --------
#  -------- discriminator_loss : 0.002558391075581312 --------
#  Generator_loss : 8.437468528747559 --------
# --------Epoch 305 --------
#  -------- discriminator_loss : 0.0030978883150964975 --------
#  Generator_loss : 6.73878288269043 --------
# --------Epoch 306 --------
#  -------- discriminator_loss : 0.0011301182676106691 --------
#  Generator_loss : 10.02880573272705 --------
# --------Epoch 307 --------
#  -------- discriminator_loss : 0.000352010247297585 --------
#  Generator_loss : 7.9744038581848145 --------
# --------Epoch 308 --------
#  -------- discriminator_loss : 0.357671856880188 --------
#  Generator_loss : 18.699926376342773 --------
# --------Epoch 309 --------
#  -------- discriminator_loss : 0.06665979325771332 --------
#  Generator_loss : 19.57860565185547 --------
# --------Epoch 310 --------
#  -------- discriminator_loss : 1.097090944313095e-06 --------
#  Generator_loss : 16.77653694152832 --------
# --------Epoch 311 --------
#  -------- discriminator_loss : 2.0856823539361358e-05 --------
#  Generator_loss : 11.556498527526855 --------
# --------Epoch 312 --------
#  -------- discriminator_loss : 0.21080100536346436 --------
#  Generator_loss : 1.702568769454956 --------
# --------Epoch 313 --------
#  -------- discriminator_loss : 0.00022885805810801685 --------
#  Generator_loss : 8.7308931350708 --------
# --------Epoch 314 --------
#  -------- discriminator_loss : 1.2393458746373653e-05 --------
#  Generator_loss : 11.477300643920898 --------
# --------Epoch 315 --------
#  -------- discriminator_loss : 3.8053381103964057e-06 --------
#  Generator_loss : 12.410356521606445 --------
# --------Epoch 316 --------
#  -------- discriminator_loss : 7.170977914938703e-05 --------
#  Generator_loss : 12.068382263183594 --------
# --------Epoch 317 --------
#  -------- discriminator_loss : 0.0005344756646081805 --------
#  Generator_loss : 10.848186492919922 --------
# --------Epoch 318 --------
#  -------- discriminator_loss : 0.006208552047610283 --------
#  Generator_loss : 7.812502861022949 --------
# --------Epoch 319 --------
#  -------- discriminator_loss : 0.04132932052016258 --------
#  Generator_loss : 7.196319103240967 --------
# --------Epoch 320 --------
#  -------- discriminator_loss : 0.000383419799618423 --------
#  Generator_loss : 9.7041015625 --------
# --------Epoch 321 --------
#  -------- discriminator_loss : 0.0009270983282476664 --------
#  Generator_loss : 10.661231994628906 --------
# --------Epoch 322 --------
#  -------- discriminator_loss : 0.00852799043059349 --------
#  Generator_loss : 10.758328437805176 --------
# --------Epoch 323 --------
#  -------- discriminator_loss : 0.01254499051719904 --------
#  Generator_loss : 10.097247123718262 --------
# --------Epoch 324 --------
#  -------- discriminator_loss : 0.022617315873503685 --------
#  Generator_loss : 10.164217948913574 --------
# --------Epoch 325 --------
#  -------- discriminator_loss : 0.05081015080213547 --------
#  Generator_loss : 10.571276664733887 --------
# --------Epoch 326 --------
#  -------- discriminator_loss : 0.021044759079813957 --------
#  Generator_loss : 9.862579345703125 --------
# --------Epoch 327 --------
#  -------- discriminator_loss : 0.03846710920333862 --------
#  Generator_loss : 7.892735481262207 --------
# --------Epoch 328 --------
#  -------- discriminator_loss : 0.007579588331282139 --------
#  Generator_loss : 5.979358673095703 --------
# --------Epoch 329 --------
#  -------- discriminator_loss : 0.028878936544060707 --------
#  Generator_loss : 6.426756858825684 --------
# --------Epoch 330 --------
#  -------- discriminator_loss : 0.008491626009345055 --------
#  Generator_loss : 7.600121021270752 --------
# --------Epoch 331 --------
#  -------- discriminator_loss : 0.04765749350190163 --------
#  Generator_loss : 7.7811598777771 --------
# --------Epoch 332 --------
#  -------- discriminator_loss : 0.07452861964702606 --------
#  Generator_loss : 5.838502407073975 --------
# --------Epoch 333 --------
#  -------- discriminator_loss : 0.0064771841280162334 --------
#  Generator_loss : 8.062957763671875 --------
# --------Epoch 334 --------
#  -------- discriminator_loss : 0.014984022825956345 --------
#  Generator_loss : 9.208867073059082 --------
# --------Epoch 335 --------
#  -------- discriminator_loss : 0.00440144632011652 --------
#  Generator_loss : 7.56824254989624 --------
# --------Epoch 336 --------
#  -------- discriminator_loss : 0.01192487683147192 --------
#  Generator_loss : 5.186297416687012 --------
# --------Epoch 337 --------
#  -------- discriminator_loss : 0.02983907237648964 --------
#  Generator_loss : 3.7301394939422607 --------
# --------Epoch 338 --------
#  -------- discriminator_loss : 0.0068445028737187386 --------
#  Generator_loss : 7.807509422302246 --------
# --------Epoch 339 --------
#  -------- discriminator_loss : 0.08215884864330292 --------
#  Generator_loss : 9.395718574523926 --------
# --------Epoch 340 --------
#  -------- discriminator_loss : 0.0034329406917095184 --------
#  Generator_loss : 8.047399520874023 --------
# --------Epoch 341 --------
#  -------- discriminator_loss : 0.009535285644233227 --------
#  Generator_loss : 5.553188800811768 --------
# --------Epoch 342 --------
#  -------- discriminator_loss : 0.02588037960231304 --------
#  Generator_loss : 4.277474880218506 --------
# --------Epoch 343 --------
#  -------- discriminator_loss : 0.0018411963246762753 --------
#  Generator_loss : 7.1657328605651855 --------
# --------Epoch 344 --------
#  -------- discriminator_loss : 0.003741644788533449 --------
#  Generator_loss : 8.767721176147461 --------
# --------Epoch 345 --------
#  -------- discriminator_loss : 0.011096453294157982 --------
#  Generator_loss : 8.335429191589355 --------
# --------Epoch 346 --------
#  -------- discriminator_loss : 0.014001247473061085 --------
#  Generator_loss : 6.464575290679932 --------
# --------Epoch 347 --------
#  -------- discriminator_loss : 0.01165011990815401 --------
#  Generator_loss : 4.995711326599121 --------
# --------Epoch 348 --------
#  -------- discriminator_loss : 0.006814081687480211 --------
#  Generator_loss : 6.724757194519043 --------
# --------Epoch 349 --------
#  -------- discriminator_loss : 0.0024346299469470978 --------
#  Generator_loss : 7.2928056716918945 --------
# --------Epoch 350 --------
#  -------- discriminator_loss : 0.0039720986969769 --------
#  Generator_loss : 6.08403205871582 --------
# --------Epoch 351 --------
#  -------- discriminator_loss : 0.015093380585312843 --------
#  Generator_loss : 4.886041641235352 --------
# --------Epoch 352 --------
#  -------- discriminator_loss : 0.009416954591870308 --------
#  Generator_loss : 7.978662014007568 --------
# --------Epoch 353 --------
#  -------- discriminator_loss : 0.0022641397081315517 --------
#  Generator_loss : 7.979380130767822 --------
# --------Epoch 354 --------
#  -------- discriminator_loss : 0.005585487466305494 --------
#  Generator_loss : 5.427282810211182 --------
# --------Epoch 355 --------
#  -------- discriminator_loss : 0.005859930068254471 --------
#  Generator_loss : 5.004512786865234 --------
# --------Epoch 356 --------
#  -------- discriminator_loss : 0.0010580160887911916 --------
#  Generator_loss : 7.115162372589111 --------
# --------Epoch 357 --------
#  -------- discriminator_loss : 0.0006394356023520231 --------
#  Generator_loss : 8.114681243896484 --------
# --------Epoch 358 --------
# ...
# --------Epoch 883 --------
#  -------- discriminator_loss : 0.0018579940078780055 --------
#  Generator_loss : 9.120139122009277 --------
# --------Epoch 884 --------
#  -------- discriminator_loss : 0.0003230562142562121 --------
#  Generator_loss : 8.799174308776855 --------
# --------Epoch 885 --------
#  -------- discriminator_loss : 0.0018594606081023812 --------
#  Generator_loss : 6.983266830444336 --------
# --------Epoch 886 --------
#  -------- discriminator_loss : 0.0023786977399140596 --------
#  Generator_loss : 6.0698771476745605 --------
# --------Epoch 887 --------
#  -------- discriminator_loss : 0.003829682245850563 --------
#  Generator_loss : 13.337034225463867 --------
# --------Epoch 888 --------
#  -------- discriminator_loss : 2.9961109248688444e-05 --------
#  Generator_loss : 11.660951614379883 --------
# --------Epoch 889 --------
#  -------- discriminator_loss : 5.226522625889629e-05 --------
#  Generator_loss : 11.05207633972168 --------
# --------Epoch 890 --------
#  -------- discriminator_loss : 2.5435727366129868e-05 --------
#  Generator_loss : 15.534711837768555 --------
# --------Epoch 891 --------
#  -------- discriminator_loss : 0.00015190592966973782 --------
#  Generator_loss : 17.989948272705078 --------
# --------Epoch 892 --------
#  -------- discriminator_loss : 0.0012680438812822104 --------
#  Generator_loss : 16.150135040283203 --------
# --------Epoch 893 --------
#  -------- discriminator_loss : 0.0004321089945733547 --------
#  Generator_loss : 16.58309555053711 --------
# --------Epoch 894 --------
#  -------- discriminator_loss : 0.0007918791961856186 --------
#  Generator_loss : 16.7644100189209 --------
# --------Epoch 895 --------
#  -------- discriminator_loss : 0.000999612850137055 --------
#  Generator_loss : 13.974924087524414 --------
# --------Epoch 896 --------
#  -------- discriminator_loss : 0.0015583367785438895 --------
#  Generator_loss : 14.73935604095459 --------
# --------Epoch 897 --------
#  -------- discriminator_loss : 0.0016129909781739116 --------
#  Generator_loss : 12.280004501342773 --------
# --------Epoch 898 --------
#  -------- discriminator_loss : 0.0031528461258858442 --------
#  Generator_loss : 12.771010398864746 --------
# --------Epoch 899 --------
#  -------- discriminator_loss : 0.000670868786983192 --------
#  Generator_loss : 11.045724868774414 --------
# --------Epoch 900 --------
#  -------- discriminator_loss : 0.0027614617720246315 --------
#  Generator_loss : 6.506418228149414 --------
# --------Epoch 901 --------
#  -------- discriminator_loss : 0.021838756278157234 --------
#  Generator_loss : 15.11159896850586 --------
# --------Epoch 902 --------
#  -------- discriminator_loss : 0.0034984031226485968 --------
#  Generator_loss : 18.583782196044922 --------
# --------Epoch 903 --------
#  -------- discriminator_loss : 0.00011348703992553055 --------
#  Generator_loss : 19.299964904785156 --------
# --------Epoch 904 --------
#  -------- discriminator_loss : 0.001209103036671877 --------
#  Generator_loss : 19.971099853515625 --------
# --------Epoch 905 --------
#  -------- discriminator_loss : 0.0008226889767684042 --------
#  Generator_loss : 17.268129348754883 --------
# --------Epoch 906 --------
#  -------- discriminator_loss : 0.000286608817987144 --------
#  Generator_loss : 15.585806846618652 --------
# --------Epoch 907 --------
#  -------- discriminator_loss : 0.0032696756534278393 --------
#  Generator_loss : 15.187804222106934 --------
# --------Epoch 908 --------
#  -------- discriminator_loss : 0.0005274127470329404 --------
#  Generator_loss : 12.738152503967285 --------
# --------Epoch 909 --------
#  -------- discriminator_loss : 0.0022118943743407726 --------
#  Generator_loss : 13.51024055480957 --------
# --------Epoch 910 --------
#  -------- discriminator_loss : 0.0037523398641496897 --------
#  Generator_loss : 12.833195686340332 --------
# --------Epoch 911 --------
#  -------- discriminator_loss : 0.001102520152926445 --------
#  Generator_loss : 11.057669639587402 --------
# --------Epoch 912 --------
#  -------- discriminator_loss : 0.002645671833306551 --------
#  Generator_loss : 11.015791893005371 --------
# --------Epoch 913 --------
#  -------- discriminator_loss : 0.0033626959193497896 --------
#  Generator_loss : 12.792777061462402 --------
# --------Epoch 914 --------
#  -------- discriminator_loss : 0.00041046287515200675 --------
#  Generator_loss : 13.831721305847168 --------
# --------Epoch 915 --------
#  -------- discriminator_loss : 0.001370777958072722 --------
#  Generator_loss : 10.643156051635742 --------
# --------Epoch 916 --------
#  -------- discriminator_loss : 0.013009689748287201 --------
#  Generator_loss : 7.864285469055176 --------
# --------Epoch 917 --------
#  -------- discriminator_loss : 0.0009434205712750554 --------
#  Generator_loss : 10.534482955932617 --------
# --------Epoch 918 --------
#  -------- discriminator_loss : 0.009980454109609127 --------
#  Generator_loss : 11.785679817199707 --------
# --------Epoch 919 --------
#  -------- discriminator_loss : 0.0005285600200295448 --------
#  Generator_loss : 10.040483474731445 --------
# --------Epoch 920 --------
#  -------- discriminator_loss : 0.007918517105281353 --------
#  Generator_loss : 6.432825088500977 --------
# --------Epoch 921 --------
#  -------- discriminator_loss : 0.00042854895582422614 --------
#  Generator_loss : 8.466734886169434 --------
# --------Epoch 922 --------
#  -------- discriminator_loss : 0.006158721633255482 --------
#  Generator_loss : 11.667877197265625 --------
# --------Epoch 923 --------
#  -------- discriminator_loss : 0.0024753217585384846 --------
#  Generator_loss : 9.991604804992676 --------
# --------Epoch 924 --------
#  -------- discriminator_loss : 0.0006048801587894559 --------
#  Generator_loss : 11.570771217346191 --------
# --------Epoch 925 --------
#  -------- discriminator_loss : 0.0010656872764229774 --------
#  Generator_loss : 11.951560974121094 --------
# --------Epoch 926 --------
#  -------- discriminator_loss : 0.0022774110548198223 --------
#  Generator_loss : 11.724130630493164 --------
# --------Epoch 927 --------
#  -------- discriminator_loss : 0.002081099431961775 --------
#  Generator_loss : 11.990690231323242 --------
# --------Epoch 928 --------
#  -------- discriminator_loss : 0.000715258065611124 --------
#  Generator_loss : 10.281742095947266 --------
# --------Epoch 929 --------
#  -------- discriminator_loss : 0.0019402659963816404 --------
#  Generator_loss : 9.495397567749023 --------
# --------Epoch 930 --------
#  -------- discriminator_loss : 0.0021895822137594223 --------
#  Generator_loss : 8.093100547790527 --------
# --------Epoch 931 --------
#  -------- discriminator_loss : 0.001673863735049963 --------
#  Generator_loss : 7.78810977935791 --------
# --------Epoch 932 --------
#  -------- discriminator_loss : 0.003498070640489459 --------
#  Generator_loss : 5.964783668518066 --------
# --------Epoch 933 --------
#  -------- discriminator_loss : 0.0018828387837857008 --------
#  Generator_loss : 7.592230319976807 --------
# --------Epoch 934 --------
#  -------- discriminator_loss : 0.0021356965880841017 --------
#  Generator_loss : 9.494914054870605 --------
# --------Epoch 935 --------
#  -------- discriminator_loss : 0.002025983761996031 --------
#  Generator_loss : 8.854349136352539 --------
# --------Epoch 936 --------
#  -------- discriminator_loss : 0.0019049833063036203 --------
#  Generator_loss : 7.147401332855225 --------
# --------Epoch 937 --------
#  -------- discriminator_loss : 0.00201049679890275 --------
#  Generator_loss : 6.743672847747803 --------
# --------Epoch 938 --------
#  -------- discriminator_loss : 0.0005164347239769995 --------
#  Generator_loss : 9.065813064575195 --------
# --------Epoch 939 --------
#  -------- discriminator_loss : 0.00020739302271977067 --------
#  Generator_loss : 9.895977020263672 --------
# --------Epoch 940 --------
#  -------- discriminator_loss : 0.00011210270167794079 --------
#  Generator_loss : 9.836416244506836 --------
# --------Epoch 941 --------
#  -------- discriminator_loss : 0.00020131547353230417 --------
#  Generator_loss : 9.331987380981445 --------
# --------Epoch 942 --------
#  -------- discriminator_loss : 0.00029047613497823477 --------
#  Generator_loss : 8.290315628051758 --------
# --------Epoch 943 --------
#  -------- discriminator_loss : 0.00033384529524482787 --------
#  Generator_loss : 7.988330841064453 --------
# --------Epoch 944 --------
#  -------- discriminator_loss : 0.0005723242647945881 --------
#  Generator_loss : 7.819952487945557 --------
# --------Epoch 945 --------
#  -------- discriminator_loss : 0.0005498324753716588 --------
#  Generator_loss : 8.064163208007812 --------
# --------Epoch 946 --------
#  -------- discriminator_loss : 0.00026825242093764246 --------
#  Generator_loss : 10.413494110107422 --------
# --------Epoch 947 --------
#  -------- discriminator_loss : 0.003392699873074889 --------
#  Generator_loss : 9.72596263885498 --------
# --------Epoch 948 --------
#  -------- discriminator_loss : 0.0004223829018883407 --------
#  Generator_loss : 9.368783950805664 --------
# --------Epoch 949 --------
#  -------- discriminator_loss : 0.0026816679164767265 --------
#  Generator_loss : 8.115765571594238 --------
# --------Epoch 950 --------
#  -------- discriminator_loss : 0.0011455734493210912 --------
#  Generator_loss : 7.712841033935547 --------
# --------Epoch 951 --------
#  -------- discriminator_loss : 0.00034139162744395435 --------
#  Generator_loss : 9.80784797668457 --------
# --------Epoch 952 --------
#  -------- discriminator_loss : 0.0011784039670601487 --------
#  Generator_loss : 9.17818832397461 --------
# --------Epoch 953 --------
#  -------- discriminator_loss : 0.0005060086259618402 --------
#  Generator_loss : 8.937851905822754 --------
# --------Epoch 954 --------
#  -------- discriminator_loss : 0.000981498509645462 --------
#  Generator_loss : 8.939427375793457 --------
# --------Epoch 955 --------
#  -------- discriminator_loss : 0.0012027721386402845 --------
#  Generator_loss : 7.593381881713867 --------
# --------Epoch 956 --------
#  -------- discriminator_loss : 0.0005947599420323968 --------
#  Generator_loss : 7.868711471557617 --------
# --------Epoch 957 --------
#  -------- discriminator_loss : 0.00018851077766157687 --------
#  Generator_loss : 9.955872535705566 --------
# --------Epoch 958 --------
#  -------- discriminator_loss : 0.0004938395577482879 --------
#  Generator_loss : 8.390141487121582 --------
# --------Epoch 959 --------
#  -------- discriminator_loss : 0.0014236667193472385 --------
#  Generator_loss : 9.006603240966797 --------
# --------Epoch 960 --------
#  -------- discriminator_loss : 0.0005398461362347007 --------
#  Generator_loss : 8.646759033203125 --------
# --------Epoch 961 --------
#  -------- discriminator_loss : 0.0005150061915628612 --------
#  Generator_loss : 8.093992233276367 --------
# --------Epoch 962 --------
#  -------- discriminator_loss : 0.0006642973748967052 --------
#  Generator_loss : 8.523999214172363 --------
# --------Epoch 963 --------
#  -------- discriminator_loss : 0.0008164104074239731 --------
#  Generator_loss : 7.3646392822265625 --------
# --------Epoch 964 --------
#  -------- discriminator_loss : 0.0011965399608016014 --------
#  Generator_loss : 7.888092994689941 --------
# --------Epoch 965 --------
#  -------- discriminator_loss : 0.0015318108489736915 --------
#  Generator_loss : 7.7626729011535645 --------
# --------Epoch 966 --------
#  -------- discriminator_loss : 0.001745123416185379 --------
#  Generator_loss : 6.715768337249756 --------
# --------Epoch 967 --------
#  -------- discriminator_loss : 0.0005274503491818905 --------
#  Generator_loss : 9.291086196899414 --------
# --------Epoch 968 --------
#  -------- discriminator_loss : 0.00015496490232180804 --------
#  Generator_loss : 10.850251197814941 --------
# --------Epoch 969 --------
#  -------- discriminator_loss : 0.00019051769049838185 --------
#  Generator_loss : 9.563642501831055 --------
# --------Epoch 970 --------
#  -------- discriminator_loss : 0.0005075852386653423 --------
#  Generator_loss : 8.357820510864258 --------
# --------Epoch 971 --------
#  -------- discriminator_loss : 0.0014875293709337711 --------
#  Generator_loss : 6.725098133087158 --------
# --------Epoch 972 --------
#  -------- discriminator_loss : 0.00030899071134626865 --------
#  Generator_loss : 8.65410327911377 --------
# --------Epoch 973 --------
#  -------- discriminator_loss : 0.001322181080467999 --------
#  Generator_loss : 7.447301387786865 --------
# --------Epoch 974 --------
#  -------- discriminator_loss : 0.0041963281109929085 --------
#  Generator_loss : 5.588143348693848 --------
# --------Epoch 975 --------
#  -------- discriminator_loss : 0.005828686524182558 --------
#  Generator_loss : 9.495575904846191 --------
# --------Epoch 976 --------
#  -------- discriminator_loss : 0.002088925102725625 --------
#  Generator_loss : 7.067580699920654 --------
# --------Epoch 977 --------
#  -------- discriminator_loss : 0.0003164561640005559 --------
#  Generator_loss : 7.928514003753662 --------
# --------Epoch 978 --------
#  -------- discriminator_loss : 0.0003013251116499305 --------
#  Generator_loss : 7.847209930419922 --------
# --------Epoch 979 --------
#  -------- discriminator_loss : 0.002464557997882366 --------
#  Generator_loss : 6.729456901550293 --------
# --------Epoch 980 --------
#  -------- discriminator_loss : 7.937649206724018e-05 --------
#  Generator_loss : 10.136186599731445 --------
# --------Epoch 981 --------
#  -------- discriminator_loss : 3.0188088203431107e-05 --------
#  Generator_loss : 11.350519180297852 --------
# --------Epoch 982 --------
#  -------- discriminator_loss : 9.715970372781157e-05 --------
#  Generator_loss : 10.098099708557129 --------
# --------Epoch 983 --------
#  -------- discriminator_loss : 0.000393975293263793 --------
#  Generator_loss : 8.586414337158203 --------
# --------Epoch 984 --------
#  -------- discriminator_loss : 0.00035851445863954723 --------
#  Generator_loss : 8.573417663574219 --------
# --------Epoch 985 --------
#  -------- discriminator_loss : 0.00018185790395364165 --------
#  Generator_loss : 9.211092948913574 --------
# --------Epoch 986 --------
#  -------- discriminator_loss : 0.0007247673929668963 --------
#  Generator_loss : 7.519880294799805 --------
# --------Epoch 987 --------
#  -------- discriminator_loss : 0.0014901567483320832 --------
#  Generator_loss : 6.403284072875977 --------
# --------Epoch 988 --------
#  -------- discriminator_loss : 0.00022896613518241793 --------
#  Generator_loss : 8.836216926574707 --------
# --------Epoch 989 --------
#  -------- discriminator_loss : 0.0031594885513186455 --------
#  Generator_loss : 10.786225318908691 --------
# --------Epoch 990 --------
#  -------- discriminator_loss : 0.0007101528462953866 --------
#  Generator_loss : 9.299403190612793 --------
# --------Epoch 991 --------
#  -------- discriminator_loss : 0.00072245963383466 --------
#  Generator_loss : 8.643543243408203 --------
# --------Epoch 992 --------
#  -------- discriminator_loss : 0.0001770615781424567 --------
#  Generator_loss : 9.321633338928223 --------
# --------Epoch 993 --------
#  -------- discriminator_loss : 6.116890290286392e-05 --------
#  Generator_loss : 10.177094459533691 --------
# --------Epoch 994 --------
#  -------- discriminator_loss : 9.098754526348785e-05 --------
#  Generator_loss : 11.65982723236084 --------
# --------Epoch 995 --------
#  -------- discriminator_loss : 2.744489029282704e-05 --------
#  Generator_loss : 10.792391777038574 --------
# --------Epoch 996 --------
#  -------- discriminator_loss : 0.002179196570068598 --------
#  Generator_loss : 7.0171332359313965 --------
# --------Epoch 997 --------
#  -------- discriminator_loss : 0.0004010883567389101 --------
#  Generator_loss : 9.333186149597168 --------
# --------Epoch 998 --------
#  -------- discriminator_loss : 8.654542762087658e-05 --------
#  Generator_loss : 10.755661964416504 --------
# --------Epoch 999 --------
#  -------- discriminator_loss : 5.947250974713825e-05 --------
#  Generator_loss : 10.436630249023438 --------
# --------Epoch 1000 --------
#  -------- discriminator_loss : 0.00018310494488105178 --------
#  Generator_loss : 8.877981185913086 --------
